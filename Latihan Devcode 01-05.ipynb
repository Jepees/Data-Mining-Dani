# %% [markdown]
# 1. Jujutsu Kaisen

# %%
star = '*'
def jumlahBayangan(jumlahRohGedungA, jumlahRohGedungB):
    return 2*(jumlahRohGedungA+jumlahRohGedungB)

#ketentuan: 1 bayangan bisa bunuh 2 roh. berapa bayangan untuk bunuh roh di kedua gedung?
S1_JJK = [[4,6],[3,5],[1,2]]
J1_JJK = [20, 16, 6]
for i in range(len(S1_JJK)):
    print(f'KASUS {i+1}')
    print(f'input: jumlahRohGedungA = {S1_JJK[i][0]}, jumlahRohGedungB = {S1_JJK[i][0]}')
    print(f'expected output: {J1_JJK[i]}')
    print(f'your output: {jumlahBayangan(S1_JJK[i][0], S1_JJK[i][1])}')
    if jumlahBayangan(S1_JJK[i][0], S1_JJK[i][1]) == J1_JJK[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: jumlahRohGedungA = 4, jumlahRohGedungB = 4
# expected output: 20
# your output: 20
# Bener Coy
#
# KASUS 2
# input: jumlahRohGedungA = 3, jumlahRohGedungB = 3
# expected output: 16
# your output: 16
# Bener Coy
#
# KASUS 3
# input: jumlahRohGedungA = 1, jumlahRohGedungB = 1
# expected output: 6
# your output: 6
# Bener Coy

# %%
star = '**'
def memecahkanKode(kode):
    jawaban = ''
    for i in kode:
        if i.isnumeric():
            jawaban+=i
    return jawaban


#ketentuan: fungsi harus mengembalikan string berupa angka2 yang terdapat dalam input
S2_JJK = ['KD89L3K1A2BD', 'H21P45A8XSP', 'X42A3L4D5']
J2_JJK = ['89312', '21458', '42345']
for i in range(len(S2_JJK)):
    print(f'KASUS {i+1}')
    print(f'input: kode = {S2_JJK[i]}')
    print(f'expected output: {J2_JJK[i]}')
    print(f'your output: {memecahkanKode(S2_JJK[i])}')
    if memecahkanKode(S2_JJK[i]) == J2_JJK[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: kode = KD89L3K1A2BD
# expected output: 89312
# your output: 89312
# Bener Coy
#
# KASUS 2
# input: kode = H21P45A8XSP
# expected output: 21458
# your output: 21458
# Bener Coy
#
# KASUS 3
# input: kode = X42A3L4D5
# expected output: 42345
# your output: 42345
# Bener Coy

# %%
star = '**'
def pemenangPertarungan(yujiItadori, rohKutukan):
    SYuji = 0
    SRoh = 0
    imbang = 0
    for i in range(len(yujiItadori)):
        if yujiItadori[i] > rohKutukan[i]:
            SYuji += 1
        elif yujiItadori[i] < rohKutukan[i]:
            SRoh += 1
        else:
            imbang += 1
    if SYuji > SRoh:
        return 'Yuji Itadori'
    elif SYuji < SRoh:
        return 'Roh Kutukan'
    else:
        return 'Keduanya Imbang'


#ketentuan: siapa yang menang? 
S3_JJK = [[[100,80,90],[90,80,70]], [[80,80,90],[100,90,90]], [[70,80,90],[90,70,90]]]
J3_JJK = ['Yuji Itadori', 'Roh Kutukan', 'Keduanya Imbang']
for i in range(len(S3_JJK)):
    print(f'KASUS {i+1}')
    print(f'input: YujiItadori = {S3_JJK[i][0]}, RohKutukan = {S3_JJK[i][0]}')
    print(f'expected output: {J3_JJK[i]}')
    print(f'your output: {pemenangPertarungan(S3_JJK[i][0], S3_JJK[i][1])}')
    if pemenangPertarungan(S3_JJK[i][0], S3_JJK[i][1]) == J3_JJK[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: YujiItadori = [100, 80, 90], RohKutukan = [100, 80, 90]
# expected output: Yuji Itadori
# your output: Yuji Itadori
# Bener Coy
#
# KASUS 2
# input: YujiItadori = [80, 80, 90], RohKutukan = [80, 80, 90]
# expected output: Roh Kutukan
# your output: Roh Kutukan
# Bener Coy
#
# KASUS 3
# input: YujiItadori = [70, 80, 90], RohKutukan = [70, 80, 90]
# expected output: Keduanya Imbang
# your output: Keduanya Imbang
# Bener Coy

# %% [markdown]
# 2. Sumpah Pemuda 2023

# %%
star = '*'
def teksSumpahPemuda(poin):
    SumpahPemuda = ['KALIMAT TIDAK DITEMUKAN',
                    'KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERTUMPAH DARAH YANG SATU TANAH AIR INDONESIA',
                    'KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERBANGSA YANG SATU BANGSA INDONESIA',
                    'KAMI PUTRA DAN PUTRI INDONESIA MENJUNJUNG BAHASA PERSATUAN BAHASA INDONESIA']
    for i in range(len(SumpahPemuda)):
        if poin not in range(len(SumpahPemuda)):
            return SumpahPemuda[0]
        elif poin == i:
            return SumpahPemuda[i]


#ketentuan: keluarin teks sumpah pemuda sesuai inpiut, kalo input bukan [1,3] maka keluarin kalimat gaada
S1_Pemuda23 = [1,2,3,4]
J1_Pemuda23 = ['KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERTUMPAH DARAH YANG SATU TANAH AIR INDONESIA', 'KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERBANGSA YANG SATU BANGSA INDONESIA', 'KAMI PUTRA DAN PUTRI INDONESIA MENJUNJUNG BAHASA PERSATUAN BAHASA INDONESIA', 'KALIMAT TIDAK DITEMUKAN']
for i in range(len(S1_Pemuda23)):
    print(f'KASUS {i+1}')
    print(f'input: Poin = {S1_Pemuda23[i]}')
    print(f'expected output: {J1_Pemuda23[i]}')
    print(f'your output: {teksSumpahPemuda(S1_Pemuda23[i])}')
    if teksSumpahPemuda(S1_Pemuda23[i]) == J1_Pemuda23[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: Poin = 1
# expected output: KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERTUMPAH DARAH YANG SATU TANAH AIR INDONESIA
# your output: KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERTUMPAH DARAH YANG SATU TANAH AIR INDONESIA
# Bener Coy
#
# KASUS 2
# input: Poin = 2
# expected output: KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERBANGSA YANG SATU BANGSA INDONESIA
# your output: KAMI PUTRA DAN PUTRI INDONESIA MENGAKU BERBANGSA YANG SATU BANGSA INDONESIA
# Bener Coy
#
# KASUS 3
# input: Poin = 3
# expected output: KAMI PUTRA DAN PUTRI INDONESIA MENJUNJUNG BAHASA PERSATUAN BAHASA INDONESIA
# your output: KAMI PUTRA DAN PUTRI INDONESIA MENJUNJUNG BAHASA PERSATUAN BAHASA INDONESIA
# Bener Coy
#
# KASUS 4
# input: Poin = 4
# expected output: KALIMAT TIDAK DITEMUKAN
# your output: KALIMAT TIDAK DITEMUKAN
# Bener Coy

# %%
star = '***'
def konversiBiner(pesanBiner):
    hasil = 0
    for i in range(len(pesanBiner)-1, -1, -1):
        hasil += int(pesanBiner[i])*(2**abs(i-len(pesanBiner)+1))
    return hasil

#ketentuan: konversi biner ke desimal
S2_Pemuda23 = ['11011', '11100', '1010', '11110001000']
J2_Pemuda23 = [27, 28, 10, 1928]
for i in range(len(S2_Pemuda23)):
    print(f'KASUS {i+1}')
    print(f'input: PesanBiner = {S2_Pemuda23[i]}')
    print(f'expected output: {J2_Pemuda23[i]}')
    print(f'your output: {konversiBiner(S2_Pemuda23[i])}')
    if konversiBiner(S2_Pemuda23[i]) == J2_Pemuda23[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: PesanBiner = 11011
# expected output: 27
# your output: 27
# Bener Coy
#
# KASUS 2
# input: PesanBiner = 11100
# expected output: 28
# your output: 28
# Bener Coy
#
# KASUS 3
# input: PesanBiner = 1010
# expected output: 10
# your output: 10
# Bener Coy
#
# KASUS 4
# input: PesanBiner = 11110001000
# expected output: 1928
# your output: 1928
# Bener Coy

# %%
star = "***"
def daftarTokohPenting(daftarNama):
    DaftarNamaPenting = ['SOENARIO SASTROWARDOYO',
                        'AMIR SYARIFUDDIN HARAHAP',
                        'MOHAMMAD YAMIN',
                        'DJOKO MARSAID',
                        'SOEGONDO DJOJOPOESPITO',
                        'JOHANNES LEIMENA',
                        'SARMIDI MANGOENSARKORO',
                        'JOHAN MOHAMMAD CAI',
                        'RUMONDOR CORNELIS LEFRAND SENDUK',
                        'MOHAMMAD ROCHJANI SUUD',
                        'R KATJA SOENGKANA',
                        'WAGE RUDOLF SOEPRATMAN',
                        'THEODORA ATHIA SALIM',]
    nama = []
    for i in daftarNama:
        if i in DaftarNamaPenting:
            nama.append(i)
    if len(nama)==0:
        return 'NAMA TOKOH PENTING TIDAK DITEMUKAN'
    else:
        return ', '.join(nama)


#ketentuan: apakah nama pada input ada pada daftar nama tokoh penting?
S3_Pemuda23 = [["MUHAMAD JAMALUDIN","MOHAMMAD YAMIN","KURLA KURYADI"], ["JOHAN MOHAMMAD CAI","SURYANO SANTOSO","THEODORA ATHIA SALIM","ATEP SUKENDAR"], ["MOHAMMAD ROCHJANI SUUD","RUMONDOR CORNELIS LEFRAND SENDUK","SARMIDI MANGOENSARKORO","JOHANNES LEIMENA"], ["BURYONO KURSUNO","PURSYANO KARTANO","BURYO SUKRO","PAPATARANANG KANARANG"]]
J3_Pemuda23 = [['MOHAMMAD YAMIN'], ['JOHAN MOHAMMAD CAI', 'THEODORA ATHIA SALIM'], ['MOHAMMAD ROCHJANI SUUD', 'RUMONDOR CORNELIS LEFRAND SENDUK', 'SARMIDI MANGOENSARKORO, JOHANNES LEIMENA'], ['NAMA TOKOH PENTING TIDAK DITEMUKAN']]
for i in range(len(S3_Pemuda23)):
    print(f'KASUS {i+1}')
    print(f'input: Daftar Nama = {S3_Pemuda23[i]}')
    print(f'expected output: {", ".join(J3_Pemuda23[i])}')
    print(f'your output: {daftarTokohPenting(S3_Pemuda23[i])}')
    if daftarTokohPenting(S3_Pemuda23[i]) == ", ".join(J3_Pemuda23[i]):
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: Daftar Nama = ['MUHAMAD JAMALUDIN', 'MOHAMMAD YAMIN', 'KURLA KURYADI']
# expected output: MOHAMMAD YAMIN
# your output: MOHAMMAD YAMIN
# Bener Coy
#
# KASUS 2
# input: Daftar Nama = ['JOHAN MOHAMMAD CAI', 'SURYANO SANTOSO', 'THEODORA ATHIA SALIM', 'ATEP SUKENDAR']
# expected output: JOHAN MOHAMMAD CAI, THEODORA ATHIA SALIM
# your output: JOHAN MOHAMMAD CAI, THEODORA ATHIA SALIM
# Bener Coy
#
# KASUS 3
# input: Daftar Nama = ['MOHAMMAD ROCHJANI SUUD', 'RUMONDOR CORNELIS LEFRAND SENDUK', 'SARMIDI MANGOENSARKORO', 'JOHANNES LEIMENA']
# expected output: MOHAMMAD ROCHJANI SUUD, RUMONDOR CORNELIS LEFRAND SENDUK, SARMIDI MANGOENSARKORO, JOHANNES LEIMENA
# your output: MOHAMMAD ROCHJANI SUUD, RUMONDOR CORNELIS LEFRAND SENDUK, SARMIDI MANGOENSARKORO, JOHANNES LEIMENA
# Bener Coy
#
# KASUS 4
# input: Daftar Nama = ['BURYONO KURSUNO', 'PURSYANO KARTANO', 'BURYO SUKRO', 'PAPATARANANG KANARANG']
# expected output: NAMA TOKOH PENTING TIDAK DITEMUKAN
# ...

# %% [markdown]
# 3. Kimetsu no Yaiba

# %%
star = '*'
def jumlahSerangan(jumlahIblis):
    a = jumlahIblis
    serang = 0
    while a > 0:
        serang += 1
        a += -29
    return serang


#ketentuan: Tanjiro = 13 Zenitsu = 7 Inosuke = 9, jumlah serangan yg mereka butuhkan?
S1_KnY = [15, 50, 200, 580]
J1_KnY = [1, 2, 7, 20]
for i in range(len(S1_KnY)):
    print(f'KASUS {i+1}')
    print(f'input: Jumlah Iblis = {S1_KnY[i]}')
    print(f'expected output: {J1_KnY[i]}')
    print(f'your output: {jumlahSerangan(S1_KnY[i])}')
    if jumlahSerangan(S1_KnY[i]) == J1_KnY[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: Jumlah Iblis = 15
# expected output: 1
# your output: 1
# Bener Coy
#
# KASUS 2
# input: Jumlah Iblis = 50
# expected output: 2
# your output: 2
# Bener Coy
#
# KASUS 3
# input: Jumlah Iblis = 200
# expected output: 7
# your output: 7
# Bener Coy
#
# KASUS 4
# input: Jumlah Iblis = 580
# expected output: 20
# your output: 20
# Bener Coy

# %%
star: '**'
def cariHashira(input):
    dataHashira = [{'Nama': "Giyu Tomioka", 'TeknikPernafasan': "Air"},
                    {'Nama': "Mitsuri Kanroji", 'TeknikPernafasan': "Cinta"},
                    {'Nama': "Obanai Iguro", 'TeknikPernafasan': "Ular"},
                    {'Nama': "Sanemi Shinazugawa", 'TeknikPernafasan': "Angin"},
                    {'Nama': "Gyomei Himejima", 'TeknikPernafasan': "Batu"},
                    {'Nama': "Muichiro Tokito", 'TeknikPernafasan': "Kabut"},
                    {'Nama': "Muichiro Tokito", 'TeknikPernafasan': "Serangga"},
                    {'Nama': "Kyojuro Rengoku", 'TeknikPernafasan': "Api"},
                    {'Nama': "Kanae Kocho", 'TeknikPernafasan': "Bunga"},
                    {'Nama': "Tengen Uzui", 'TeknikPernafasan': "Suara"}]
    
    for i in dataHashira:
        if input == i['Nama']:
            return f'Teknik Pernafasan: {i["TeknikPernafasan"]}'
        elif input == i['TeknikPernafasan']:
            return f'Nama Hashira: {i["Nama"]}'
    return 'Data tidak ditemukan'

#ketentuan: kalo input nama keluarin teknik, kalo input teknik keluarin nama, kalo ga valid kasih tau!
S2_KnY = ['Kanae Kocho', 'Bunga', ' Angin', 'Mitsuri Kanroj', 'Dani']
J2_KnY = ['Teknik Pernafasan: Bunga', 'Nama Hashira: Kanae Kocho', 'Nama Hashira: Sanemi Shinazugawa', 'Teknik Pernafasan: Cinta', 'Data tidak ditemukan']
for i in range(len(S2_KnY)):
    print(f'KASUS {i+1}')
    print(f'input: input = {S2_KnY[i]}')
    print(f'expected output: {J2_KnY[i]}')
    print(f'your output: {cariHashira(S2_KnY[i])}')
    if cariHashira(S2_KnY[i]) == J2_KnY[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: input = Kanae Kocho
# expected output: Teknik Pernafasan: Bunga
# your output: Teknik Pernafasan: Bunga
# Bener Coy
#
# KASUS 2
# input: input = Bunga
# expected output: Nama Hashira: Kanae Kocho
# your output: Nama Hashira: Kanae Kocho
# Bener Coy
#
# KASUS 3
# input: input =  Angin
# expected output: Nama Hashira: Sanemi Shinazugawa
# your output: Data tidak ditemukan
# duh masih kurang tepat nieeh!! :(
#
# KASUS 4
# input: input = Mitsuri Kanroj
# expected output: Teknik Pernafasan: Cinta
# your output: Data tidak ditemukan
# duh masih kurang tepat nieeh!! :(
#
# KASUS 5
# input: input = Dani
# expected output: Data tidak ditemukan
# your output: Data tidak ditemukan
# Bener Coy

# %%
star: '**'
def seranganHinokamiKagura(nyawaIblis):
    serangan = 0
    SisaNyawa = nyawaIblis
    while SisaNyawa > 0:
        if serangan == 13:
            break
        else:
            SisaNyawa += -(serangan+1)
            serangan += 1
    if SisaNyawa>0:
        return f'Sisa HP Iblis {SisaNyawa}'
    else:
        return f'Iblis Kalah pada Serangan ke-{serangan}'

#ketentuan: mati di serangan ke berapa jika damage serangan selalu bertambah satu dengan batas serangan 13x? jika lebih dari 13 berapa sisa nyawa iblis?
S3_KnY = [4, 45, 100, 500]
J3_KnY = ['Iblis Kalah pada Serangan ke-3', 'Iblis Kalah pada Serangan ke-9', 'Sisa HP Iblis 9', 'Sisa HP Iblis 409']
for i in range(len(S3_KnY)):
    print(f'KASUS {i+1}')
    print(f'input: HP Iblis = {S3_KnY[i]}')
    print(f'expected output: {J3_KnY[i]}')
    print(f'your output: {seranganHinokamiKagura(S3_KnY[i])}')
    if seranganHinokamiKagura(S3_KnY[i]) == J3_KnY[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: HP Iblis = 4
# expected output: Iblis Kalah pada Serangan ke-3
# your output: Iblis Kalah pada Serangan ke-3
# Bener Coy
#
# KASUS 2
# input: HP Iblis = 45
# expected output: Iblis Kalah pada Serangan ke-9
# your output: Iblis Kalah pada Serangan ke-9
# Bener Coy
#
# KASUS 3
# input: HP Iblis = 100
# expected output: Sisa HP Iblis 9
# your output: Sisa HP Iblis 9
# Bener Coy
#
# KASUS 4
# input: HP Iblis = 500
# expected output: Sisa HP Iblis 409
# your output: Sisa HP Iblis 409
# Bener Coy

# %% [markdown]
# 4. Hari Pahlawan 2023

# %%
star = '*'
def peristiwaPenting(tanggal):
    peristiwa = {'1': "Pada tanggal 1 November 1945, Laskar Hizbullah, sebuah kelompok pemuda yang dipimpin oleh Suhud, berhasil merebut alun-alun Yogyakarta dari penjajah Belanda.",
            '10': "Tanggal 10 November diperingati sebagai Hari Pahlawan untuk mengenang jasa-jasa para pejuang kemerdekaan Indonesia. Pada tanggal ini, tahun 1945, Letnan Jenderal Soedirman, panglima besar Tentara Nasional Indonesia, wafat.",
            '14': "Pada tanggal 14 November 1945, Belanda resmi mengakui kedaulatan Republik Indonesia dalam Konferensi Meja Bundar.",
            '17': "Pada tanggal 17 November 1945, memasuki bulan Muharram tahun 1365 Hijriah, Indonesia memutuskan untuk memakai kalender Hijriah sebagai kalender resmi.",
            '25': "Tanggal 25 November diperingati sebagai Hari Guru untuk menghormati peran guru dalam pendidikan di Indonesia.",
            '27': "Pada tanggal 27 November 1945, sebuah pesawat Dakota yang membawa delegasi Indonesia ke Konferensi Asia-Afrika jatuh di Bukit Tinggi, Sumatera Barat.",
            '30': "Pada tanggal 30 November 1947, Serangan Umum 1 Maret (SU 1 Maret) dimulai, yang merupakan salah satu peristiwa penting dalam perang kemerdekaan Indonesia.",}
    if str(tanggal) in peristiwa:
        return peristiwa[str(tanggal)]
    else:
        return "Tidak ada peristiwa bersejarah pada tanggal tersebut."

#ketentuan: keluarkan deskripsi singkat peristiwa pada tanggal input
S1_Pahlawan23 = [10, 17, 1, 5]
J1_Pahlawan23 = ["Tanggal 10 November diperingati sebagai Hari Pahlawan untuk mengenang jasa-jasa para pejuang kemerdekaan Indonesia. Pada tanggal ini, tahun 1945, Letnan Jenderal Soedirman, panglima besar Tentara Nasional Indonesia, wafat.",
                "Pada tanggal 17 November 1945, memasuki bulan Muharram tahun 1365 Hijriah, Indonesia memutuskan untuk memakai kalender Hijriah sebagai kalender resmi.",
                "Pada tanggal 1 November 1945, Laskar Hizbullah, sebuah kelompok pemuda yang dipimpin oleh Suhud, berhasil merebut alun-alun Yogyakarta dari penjajah Belanda.",
                "Tidak ada peristiwa bersejarah pada tanggal tersebut."]
for i in range(len(S1_Pahlawan23)):
    print(f'KASUS {i+1}')
    print(f'input: tanggal = {S1_Pahlawan23[i]}')
    print(f'expected output: {J1_Pahlawan23[i]}')
    print(f'your output: {peristiwaPenting(S1_Pahlawan23[i])}')
    if peristiwaPenting(S1_Pahlawan23[i]) == J1_Pahlawan23[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: tanggal = 10
# expected output: Tanggal 10 November diperingati sebagai Hari Pahlawan untuk mengenang jasa-jasa para pejuang kemerdekaan Indonesia. Pada tanggal ini, tahun 1945, Letnan Jenderal Soedirman, panglima besar Tentara Nasional Indonesia, wafat.
# your output: Tanggal 10 November diperingati sebagai Hari Pahlawan untuk mengenang jasa-jasa para pejuang kemerdekaan Indonesia. Pada tanggal ini, tahun 1945, Letnan Jenderal Soedirman, panglima besar Tentara Nasional Indonesia, wafat.
# Bener Coy
#
# KASUS 2
# input: tanggal = 17
# expected output: Pada tanggal 17 November 1945, memasuki bulan Muharram tahun 1365 Hijriah, Indonesia memutuskan untuk memakai kalender Hijriah sebagai kalender resmi.
# your output: Pada tanggal 17 November 1945, memasuki bulan Muharram tahun 1365 Hijriah, Indonesia memutuskan untuk memakai kalender Hijriah sebagai kalender resmi.
# Bener Coy
#
# KASUS 3
# input: tanggal = 1
# ...

# %%
star = '*'
def hitungNilaiAbjad(teks):
    hasil = 0
    abjad = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i in teks:
        hasil += abjad.index(i)+1
    return hasil

#ketentuan: 'jumlah nilai abjad pada input'
S2_Pahlawan23 = ['MERDEKA', 'BANGSA', 'KEMERDEKAAN']
J2_Pahlawan23 = [57, 44, 88]
for i in range(len(S2_Pahlawan23)):
    print(f'KASUS {i+1}')
    print(f'input: teks = {S2_Pahlawan23[i]}')
    print(f'expected output: {J2_Pahlawan23[i]}')
    print(f'your output: {hitungNilaiAbjad(S2_Pahlawan23[i])}')
    if hitungNilaiAbjad(S2_Pahlawan23[i]) == J2_Pahlawan23[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: teks = MERDEKA
# expected output: 57
# your output: 57
# Bener Coy
#
# KASUS 2
# input: teks = BANGSA
# expected output: 44
# your output: 44
# Bener Coy
#
# KASUS 3
# input: teks = KEMERDEKAAN
# expected output: 88
# your output: 88
# Bener Coy

# %%
star = '**' 
def hitungBendera(simbol):
    bendera = 0
    peringatan = 0
    for i in simbol:
        if peringatan == 3:
            break
        if i == '!':
            peringatan += 1
        else:
            bendera += 1
    return bendera

#ketentuan: setiap elemen pada input menggambarkan pengibaran bendera, jika bertemu '!' sebanyak 3x pada pengibaran selesai
S3_Pahlawan23 = ['xxyaa1!!!agaw', 'xa!ag!agav!aa', 'hkh3!y76!0xer!!!!!', 'DEVCODE']
J3_Pahlawan23 = [6, 8, 11, 7]
for i in range(len(S3_Pahlawan23)):
    print(f'KASUS {i+1}')
    print(f'input: teks = {S3_Pahlawan23[i]}')
    print(f'expected output: {J3_Pahlawan23[i]}')
    print(f'your output: {hitungBendera(S3_Pahlawan23[i])}')
    if hitungBendera(S3_Pahlawan23[i]) == J3_Pahlawan23[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: teks = xxyaa1!!!agaw
# expected output: 6
# your output: 6
# Bener Coy
#
# KASUS 2
# input: teks = xa!ag!agav!aa
# expected output: 8
# your output: 8
# Bener Coy
#
# KASUS 3
# input: teks = hkh3!y76!0xer!!!!!
# expected output: 11
# your output: 11
# Bener Coy
#
# KASUS 4
# input: teks = DEVCODE
# expected output: 7
# your output: 7
# Bener Coy

# %% [markdown]
# 5. The Marvels

# %%
star = '***'
def evakuasiBangsaSkrull(jumlahPesawat, jumlahPopulasi, kapasitasPesawat):
    selamat = jumlahPesawat*kapasitasPesawat
    sisa = jumlahPopulasi - selamat
    if selamat > jumlahPopulasi:    
        if sisa <= 0:
            return f'Bangsa Skrull yang bisa di evakuasi sebanyak {jumlahPopulasi} jiwa, dan tidak ada korban jiwa.'
        else:
            return f'Bangsa Skrull yang bisa di evakuasi sebanyak {jumlahPopulasi} jiwa, sedangkan yang tidak bisa di evakuasi ialah {sisa} jiwa.'
    else:
        if sisa <= 0:
            return f'Bangsa Skrull yang bisa di evakuasi sebanyak {selamat} jiwa, dan tidak ada korban jiwa.'
        else:
            return f'Bangsa Skrull yang bisa di evakuasi sebanyak {selamat} jiwa, sedangkan yang tidak bisa di evakuasi ialah {sisa} jiwa.'

#ketentuan: berapa banyak yang bisa kita evakuasi dan berapa yg harus mati?
S1_TheMarvels = [[20 ,1250, 50], [10, 500, 40], [13, 200, 30], [30, 3530, 60]]
J1_TheMarvels = ['Bangsa Skrull yang bisa di evakuasi sebanyak 1000 jiwa, sedangkan yang tidak bisa di evakuasi ialah 250 jiwa.',
                'Bangsa Skrull yang bisa di evakuasi sebanyak 400 jiwa, sedangkan yang tidak bisa di evakuasi ialah 100 jiwa.',
                'Bangsa Skrull yang bisa di evakuasi sebanyak 200 jiwa, dan tidak ada korban jiwa.',
                'Bangsa Skrull yang bisa di evakuasi sebanyak 1800 jiwa, sedangkan yang tidak bisa di evakuasi ialah 1730 jiwa.']
for i in range(len(S1_TheMarvels)):
    print(f'KASUS {i+1}')
    print(f'input: Jumlah Pesawat = {S1_TheMarvels[i][0]}, Jumlah Populasi = {S1_TheMarvels[i][1]}, Kapasitas Pesawat = {S1_TheMarvels[i][2]}')
    print(f'expected output: {J1_TheMarvels[i]}')
    print(f'your output: {evakuasiBangsaSkrull(S1_TheMarvels[i][0], S1_TheMarvels[i][1], S1_TheMarvels[i][2])}')
    if evakuasiBangsaSkrull(S1_TheMarvels[i][0], S1_TheMarvels[i][1], S1_TheMarvels[i][2]) == J1_TheMarvels[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: Jumlah Pesawat = 20, Jumlah Populasi = 1250, Kapasitas Pesawat = 50
# expected output: Bangsa Skrull yang bisa di evakuasi sebanyak 1000 jiwa, sedangkan yang tidak bisa di evakuasi ialah 250 jiwa.
# your output: Bangsa Skrull yang bisa di evakuasi sebanyak 1000 jiwa, sedangkan yang tidak bisa di evakuasi ialah 250 jiwa.
# Bener Coy
#
# KASUS 2
# input: Jumlah Pesawat = 10, Jumlah Populasi = 500, Kapasitas Pesawat = 40
# expected output: Bangsa Skrull yang bisa di evakuasi sebanyak 400 jiwa, sedangkan yang tidak bisa di evakuasi ialah 100 jiwa.
# your output: Bangsa Skrull yang bisa di evakuasi sebanyak 400 jiwa, sedangkan yang tidak bisa di evakuasi ialah 100 jiwa.
# Bener Coy
#
# KASUS 3
# input: Jumlah Pesawat = 13, Jumlah Populasi = 200, Kapasitas Pesawat = 30
# expected output: Bangsa Skrull yang bisa di evakuasi sebanyak 200 jiwa, dan tidak ada korban jiwa.
# your output: Bangsa Skrull yang bisa di evakuasi sebanyak 200 jiwa, dan tidak ada korban jiwa.
# ...

# %%
star: '**'
def countdownTimer(time):
    hitung = time
    isi = []
    while hitung > 0:
        if hitung == 1:
            isi.append('Bersiap')
            isi.append('Switch')
            hitung += -1
        else:
            isi.append(str(hitung))
            hitung += -1
    return isi

#ketentuan: hitung mundur tapi setelah 2 adalah bersiap lalu switch!
S2_TheMarvels = [5, 3, 8, 0 ,-2]
J2_TheMarvels = [["5","4","3","2","Bersiap","Switch"], ["3","2","Bersiap","Switch"], ["8","7","6","5","4","3","2","Bersiap","Switch"], [], []]
for i in range(len(S2_TheMarvels)):
    print(f'KASUS {i+1}')
    print(f'input: time = {S2_TheMarvels[i]}')
    print(f'expected output: {J2_TheMarvels[i]}')
    print(f'your output: {countdownTimer(S2_TheMarvels[i])}')
    if countdownTimer(S2_TheMarvels[i]) == J2_TheMarvels[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
S2_TheMarvels
# Out:
# KASUS 1
# input: time = 5
# expected output: ['5', '4', '3', '2', 'Bersiap', 'Switch']
# your output: ['5', '4', '3', '2', 'Bersiap', 'Switch']
# Bener Coy
#
# KASUS 2
# input: time = 3
# expected output: ['3', '2', 'Bersiap', 'Switch']
# your output: ['3', '2', 'Bersiap', 'Switch']
# Bener Coy
#
# KASUS 3
# input: time = 8
# expected output: ['8', '7', '6', '5', '4', '3', '2', 'Bersiap', 'Switch']
# your output: ['8', '7', '6', '5', '4', '3', '2', 'Bersiap', 'Switch']
# Bener Coy
#
# KASUS 4
# input: time = 0
# expected output: []
# your output: []
# Bener Coy
#
# KASUS 5
# input: time = -2
# expected output: []
# your output: []
# Bener Coy
# [5, 3, 8, 0, -2]

# %%
star: '***'
def pertukaranTheMarvels(formasi):
    for i in range(0, 3):
        if i == 0:
            if formasi[i] != '' and formasi[3] != '':
                formasi[i], formasi[3] = formasi[3], formasi[i]
        elif i == 1:
            if formasi[i] != '' and formasi[5] != '':
                formasi[i], formasi[5] = formasi[5], formasi[i]
        else:
            if formasi[i] != '' and formasi[4] != '':
                formasi[i], formasi[4] = formasi[4], formasi[i]
    return formasi


#ketentuan: tuker posisi, index 0-3, 1-5, 2-4
S3_TheMarvels = [["CaptainMarvel","","","CaptainRambeau","","Ms.Marvel"], ["CaptainMarvel","","Ms.Marvel","","CaptainRambeau",""], ["Ms.Marvel","","","","CaptainMarvel","CaptainRambeau"], ['', 'CaptainRambeau', '', '', 'Ms.Marvel', 'CaptainMarvel']]
J3_TheMarvels = [["CaptainRambeau","","","CaptainMarvel","","Ms.Marvel"], ["CaptainMarvel","","CaptainRambeau","","Ms.Marvel",""], ["Ms.Marvel","","","","CaptainMarvel","CaptainRambeau"], ['', 'CaptainMarvel', '', '', 'Ms.Marvel', 'CaptainRambeau']]
for i in range(len(S3_TheMarvels)):
    output = pertukaranTheMarvels(S3_TheMarvels[i])
    print(f'KASUS {i+1}')
    print(f'input: formasi = {S3_TheMarvels[i]}')
    print(f'expected output: {J3_TheMarvels[i]}')
    print(f'your output    : {output}')
    if output == J3_TheMarvels[i]:
        print ('Bener Coy\n')
    else:
        print('duh masih kurang tepat nieeh!! :(\n')
# Out:
# KASUS 1
# input: formasi = ['CaptainRambeau', '', '', 'CaptainMarvel', '', 'Ms.Marvel']
# expected output: ['CaptainRambeau', '', '', 'CaptainMarvel', '', 'Ms.Marvel']
# your output    : ['CaptainRambeau', '', '', 'CaptainMarvel', '', 'Ms.Marvel']
# Bener Coy
#
# KASUS 2
# input: formasi = ['CaptainMarvel', '', 'CaptainRambeau', '', 'Ms.Marvel', '']
# expected output: ['CaptainMarvel', '', 'CaptainRambeau', '', 'Ms.Marvel', '']
# your output    : ['CaptainMarvel', '', 'CaptainRambeau', '', 'Ms.Marvel', '']
# Bener Coy
#
# KASUS 3
# input: formasi = ['Ms.Marvel', '', '', '', 'CaptainMarvel', 'CaptainRambeau']
# expected output: ['Ms.Marvel', '', '', '', 'CaptainMarvel', 'CaptainRambeau']
# your output    : ['Ms.Marvel', '', '', '', 'CaptainMarvel', 'CaptainRambeau']
# Bener Coy
#
# KASUS 4
# input: formasi = ['', 'CaptainMarvel', '', '', 'Ms.Marvel', 'CaptainRambeau']
# expected output: ['', 'CaptainMarvel', '', '', 'Ms.Marvel', 'CaptainRambeau']
# ...
